# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitosik258/collab/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd # загружаем библиотеку и для простоты обращения в коде называем её сокращенно pd

# %%
import matplotlib.pyplot as plt # загружаем библиотеку и для простоты обращения в коде называем её сокращенно plt
# указываем, чтобы картинки отображались прямо в ноутбуке 
# %matplotlib inline

# %%
training_data = pd.read_csv('ufc_master_data.csv')
training_data.head(10)
# Out:
#   ranking                 name  age  weight gender  height  ufc_wins  \
# 0       C       Brandon Moreno   27     125   Male      67         8
# 1       1  Deiveson Figueiredo   33     125   Male      65         9
# 2       2        Askar Askarov   29     125   Male      65         3
# 3       3    Alexandre Pantoja   31     125   Male      65         8
# 4       4           Alex Perez   29     125   Male      64         6
# 5       5       Brandon Royval   29     125   Male      67         2
# 6       6      Kai Kara-France   28     125   Male      65         5
# 7       7     Rogerio Bontorin   29     125   Male      65         3
# 8       8      Matheus Nicolau   28     125   Male      66         5
# 9       9         Matt Schnell   31     125   Male      68         5
#
#    ufc_loses  ufc_draws  ufc_no_contests  mma_wins  mma_loses  mma_draws  \
# 0          2        2.0              NaN      19.0        5.0        2.0
# ...

# %%
training_data.shape
# Out:
# (617, 14)

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ranking          177 non-null    object
#  1   name             617 non-null    object
#  2   age              617 non-null    int64
#  3   weight           617 non-null    int64
#  4   gender           617 non-null    object
#  5   height           617 non-null    int64
#  6   ufc_wins         617 non-null    int64
#  7   ufc_loses        617 non-null    int64
#  8   ufc_draws        44 non-null     float64
#  9   ufc_no_contests  43 non-null     float64
#  10  mma_wins         615 non-null    float64
#  11  mma_loses        615 non-null    float64
#  12  mma_draws        82 non-null     float64
#  13  mma_no_contests  68 non-null     float64
# dtypes: float64(6), int64(5), object(3)
# memory usage: 67.6+ KB

# %%
training_data.hist(figsize=(20, 20));

# %%
training_data.head()
# Out:
#   ranking                 name  age  weight gender  height  ufc_wins  \
# 0       C       Brandon Moreno   27     125   Male      67         8
# 1       1  Deiveson Figueiredo   33     125   Male      65         9
# 2       2        Askar Askarov   29     125   Male      65         3
# 3       3    Alexandre Pantoja   31     125   Male      65         8
# 4       4           Alex Perez   29     125   Male      64         6
#
#    ufc_loses  ufc_draws  ufc_no_contests  mma_wins  mma_loses  mma_draws  \
# 0          2        2.0              NaN      19.0        5.0        2.0
# 1          2        1.0              NaN      20.0        2.0        1.0
# 2          0        1.0              NaN      14.0        0.0        1.0
# 3          3        NaN              NaN      24.0        5.0        NaN
# 4          2        NaN              NaN      24.0        6.0        NaN
#
#    mma_no_contests
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
training_data = training_data.drop('gender', axis=1)

# %%
training_values = training_data['battery_power']
